# %% [markdown]
# Data: Download the "Alzheimer's Disease.xlsx" dataset, located [here](https://osf.io/dsy37/) under "Dataset"-->"Observational Epidemiological Studies"-->"Primary Prevention". Download the dataset into the same folder as this code. Rename the dataset "AlzheimersDisease.xlsx" for better naming conventions. Later, we will also use this datset as a csv file, so you will need to also export the file as a csv.

# %%
# !pip install frictionless

# %% [markdown]
# We'll start by describing the dataset to create a resource descriptor (this file contains metadata + schema).

# %%
from frictionless import describe, resource # import these modules
from pprint import pprint # pretty print

# describe is the function that reads in data and automatically infers metadata & a schema
resource = describe('AlzheimersDisease.xlsx')
# We can directly use the Excel file

# %%
#we'll print the resource to view it
pprint(resource)
# Out:
# {'encoding': 'utf-8',
#  'format': 'xlsx',
#  'hashing': 'md5',
#  'name': 'alzheimersdisease',
#  'path': 'AlzheimersDisease.xlsx',
#  'profile': 'tabular-data-resource',
#  'schema': {'fields': [{'name': 'Outcome Being Extracted:', 'type': 'string'},
#                        {'name': "Alzheimer's disease", 'type': 'integer'},
#                        {'name': 'field3', 'type': 'string'},
#                        {'name': 'field4', 'type': 'string'},
#                        {'name': 'field5', 'type': 'string'},
#                        {'name': 'field6', 'type': 'integer'},
#                        {'name': 'field7', 'type': 'string'},
#                        {'name': 'field8', 'type': 'string'},
#                        {'name': 'field9', 'type': 'string'},
#                        {'name': 'field10', 'type': 'string'},
#                        {'name': 'field11', 'type': 'string'},
#                        {'name': 'field12', 'type': 'integer'},
#                        {'name': 'field13', 'type': 'integer'},
#                        {'name': 'field14', 'type': 'string'},
#                        {'name': 'field15', 'type': 'string'},
#                        {'name': 'field16', 'type': 'string'},
#                        {'name': 'field17', 'type': 'string'}]},
#  'scheme': 'file'}

# %% [markdown]
# Take a look at the schema. What do you see?
#
# The header names seem messed up. This is because the first few rows of data are empty. Let's use Layout to tell Frictionless that the header is row 3. (Note that we switch to the csv file here for simplicity)

# %%
from frictionless import Resource, Layout

layout = Layout(header_rows=[3])
with Resource('AlzheimersDisease.csv', layout=layout) as resource:
    pprint(resource.header)
    pprint(resource)
# more info here https://framework.frictionlessdata.io/docs/guides/framework/layout-guide/#header
# Out:
# ['AuthorOfPaper',
#  'YearOfPublication',
#  'CountryOfOrigin',
#  'StudyDesign',
#  'PhaseOfPrevention',
#  'AgeOfParticipants',
#  'MenopausalStatus',
#  'TimingOfHRT',
#  'HRTDefinition',
#  'RouteOfAdministration',
#  'LengthOfFollowUp',
#  'NumberOfCases',
#  'NumberOfPopulation',
#  'TypeOfEffectEstimate',
#  'PointEstimate',
#  'Lower95%CI',
#  'Upper95%CI']
# {'dialect': {'quoteChar': '"'},
#  'encoding': 'cp1252',
#  'format': 'csv',
#  'hashing': 'md5',
#  'layout': {'headerRows': [3]},
#  'name': 'alzheimersdisease',
#  'path': 'AlzheimersDisease.csv',
#  'profile': 'tabular-data-resource',
#  'schema': {'fields': [{'name': 'AuthorOfPaper', 'type': 'string'},
#                        {'name': 'YearOfPublication', 'type': 'any'},
#                        {'name': 'CountryOfOrigin', 'type': 'any'},
#                        {'name': 'StudyDesign', 'type': 'any'},
#                        {'name': 'PhaseOfPrevention', 'type': 'any'},
#                        {'name': 'AgeOfParticipants', 'type': 'any'},
#                        {'name': 'MenopausalStatus', 'type': 'any'},
#                        {'name': 'TimingOfHRT', 'type': 'any'},
#                        {'name': 'HRTDefinition', 'type': 'any'},
#                        {'name': 'RouteOfAdministration', 'type': 'any'},
#                        {'name': 'LengthOfFollowUp', 'type': 'any'},
#                        {'name': 'NumberOfCases', 'type': 'any'},
#                        {'name': 'NumberOfPopulation', 'type': 'any'},
#                        {'name': 'TypeOfEffectEstimate', 'type': 'any'},
#                        {'name': 'PointEstimate', 'type': 'any'},
#                        {'name': 'Lower95%CI', 'type': 'any'},
#                        {'name': 'Upper95%CI', 'type': 'any'}]},
#  'scheme': 'file',
#  'stats': {'bytes': 3167,
#            'fields': 17,
#            'hash': 'd0249d74405bce65b7b3318ac9fd9f05',
#            'rows': 0}}

# %% [markdown]
# Take a look at the schema -- how does it look now?

# %% [markdown]
# Now we can save the resource as a yaml file.

# %%
resource.to_yaml("resource.yaml")
# Out:
# 'path: AlzheimersDisease.csv\nlayout:\n  headerRows:\n    - 3\nname: alzheimersdisease\nprofile: tabular-data-resource\nscheme: file\nformat: csv\nhashing: md5\nstats:\n  hash: d0249d74405bce65b7b3318ac9fd9f05\n  bytes: 3167\n  fields: 17\n  rows: 0\nencoding: cp1252\ndialect:\n  quoteChar: \'"\'\nschema:\n  fields:\n    - type: string\n      name: AuthorOfPaper\n    - name: YearOfPublication\n      type: any\n    - name: CountryOfOrigin\n      type: any\n    - name: StudyDesign\n      type: any\n    - name: PhaseOfPrevention\n      type: any\n    - name: AgeOfParticipants\n      type: any\n    - name: MenopausalStatus\n      type: any\n    - name: TimingOfHRT\n      type: any\n    - name: HRTDefinition\n      type: any\n    - name: RouteOfAdministration\n      type: any\n    - name: LengthOfFollowUp\n      type: any\n    - name: NumberOfCases\n      type: any\n    - name: NumberOfPopulation\n      type: any\n    - name: TypeOfEffectEstimate\n      type: any\n    - name: PointEstimate\n      type: any\n    - name: Lower95%CI\n      type: any\n    - name: Upper95%CI\n      type: any\n'

# %% [markdown]
# Look at the schema + the data file. Is there anything in the schema you think need to be changed?

# %% [markdown]
# (did you look at it? if so, read on..)

# %% [markdown]
# I think the column 'LengthOfFollowUp' should be an integer instead of a string, but we would need to remove the 'y' from each value. Let's use Transform to do that. First we will split the field into 2, then we'll remove the new unit column we just created, then we'll update the data type to a number.
#
# I would add a description to the metadata that says "The unit of time is in years".

# %%
from pprint import pprint
from frictionless import Package, Resource, transform, steps

source = resource
target = transform(
    source,
    steps=[
        steps.field_split(name="LengthOfFollowUp", to_names=["LengthOfFollowUp", "UnitLengthOfFollowUp"], pattern=r"\s"),
        steps.field_remove(names=["UnitLengthOfFollowUp"]),
        steps.field_update(name="LengthOfFollowUp", type="number"),
        
    ]
)
print(target.schema)
print(target.to_view())
# more info about transform here: https://framework.frictionlessdata.io/docs/guides/transform-guide
# Out:
# {'fields': [{'type': 'string', 'name': 'AuthorOfPaper'}, {'name': 'YearOfPublication', 'type': 'any'}, {'name': 'CountryOfOrigin', 'type': 'any'}, {'name': 'StudyDesign', 'type': 'any'}, {'name': 'PhaseOfPrevention', 'type': 'any'}, {'name': 'AgeOfParticipants', 'type': 'any'}, {'name': 'MenopausalStatus', 'type': 'any'}, {'name': 'TimingOfHRT', 'type': 'any'}, {'name': 'HRTDefinition', 'type': 'any'}, {'name': 'RouteOfAdministration', 'type': 'any'}, {'name': 'NumberOfCases', 'type': 'any'}, {'name': 'NumberOfPopulation', 'type': 'any'}, {'name': 'TypeOfEffectEstimate', 'type': 'any'}, {'name': 'PointEstimate', 'type': 'any'}, {'name': 'Lower95%CI', 'type': 'any'}, {'name': 'Upper95%CI', 'type': 'any'}, {'name': 'LengthOfFollowUp', 'type': 'number'}]}
# +---------------+-------------------+-----------------+----------------+-------------------+-------------------+-------------------------+-------------+---------------+-----------------------+---------------+--------------------+----------------------+---------------+------------+------------+------------------+
# | AuthorOfPaper | YearOfPublication | CountryOfOrigin | StudyDesign    | PhaseOfPrevention | AgeOfParticipants | MenopausalStatus        | TimingOfHRT | HRTDefinition | RouteOfAdministration | NumberOfCases | NumberOfPopulation | TypeOfEffectEstimate | PointEstimate | Lower95%CI | Upper95%CI | LengthOfFollowUp |
# +===============+===================+=================+================+===================+===================+=========================+=============+===============+=======================+===============+====================+======================+===============+============+============+==================+
# | 'Brenner'     | '1994'            | 'USA'           | 'Case-control' | 'Primary'         | '78'              | 'NG'                    | 'Ever'      | 'Estrogen'    | 'Any'                 | '107'         | '120'              | 'OR'                 | '1.1'         | '0.6'      | '1.8'      | None             |
# +---------------+-------------------+-----------------+----------------+-------------------+-------------------+-------------------------+-------------+---------------+-----------------------+---------------+--------------------+----------------------+---------------+------------+------------+------------------+
# | 'Graves'      | '1990'            | 'USA'           | 'Case-control' | 'Primary'         | '65'              | 'NG'                    | 'Ever'      | 'Estrogen'    | 'Any'                 | '60'          | '60'               | 'OR'                 | '1.15'        | '0.50'     | '2.64'     | None             |
# +---------------+-------------------+-----------------+----------------+-------------------+-------------------+-------------------------+-------------+---------------+-----------------------+---------------+--------------------+----------------------+---------------+------------+------------+------------------+
# | 'Kawas'       | '1997'            | 'USA'           | 'Cohort'       | 'Primary'         | '62'              | 'Peri-/post-menopausal' | 'Ever'      | 'Estrogen'    | 'Oral/transdermal'    | '34'          | '472'              | 'HR'                 | '0.46'        | '0.21'     | '1.00'     | Decimal('16')    |
# +---------------+-------------------+-----------------+----------------+-------------------+-------------------+-------------------------+-------------+---------------+-----------------------+---------------+--------------------+----------------------+---------------+------------+------------+------------------+
# | 'Lerner'      | '1997'            | 'USA'           | 'Case-control' | 'Primary'         | '> 70'            | 'NG'                    | 'Ever'      | 'Estrogen'    | 'Any'                 | '88'          | '176'              | 'OR'                 | '0.91'        | '0.28'     | '1.54'     | None             |
# +---------------+-------------------+-----------------+----------------+-------------------+-------------------+-------------------------+-------------+---------------+-----------------------+---------------+--------------------+----------------------+---------------+------------+------------+------------------+
# | 'Lindsay'     | '2002'            | 'Canada'        | 'Cohort'       | 'Primary'         | '73'              | 'NG'                    | 'Ever'      | 'Estrogen'    | 'Any'                 | '110'         | '2079'             | 'OR'                 | '1.37'        | '0.48'     | '3.95'     | Decimal('5')     |
# +---------------+-------------------+-----------------+----------------+-------------------+-------------------+-------------------------+-------------+---------------+-----------------------+---------------+--------------------+----------------------+---------------+------------+------------+------------------+
# ...

# %% [markdown]
# Note: when I saved my excel file to csv, the formatting got weird, so all my data types are now 'any'. We can update that using Transform like you saw earlier...

# %% [markdown]
# We can now save our newly transformed data file using write.

# %%
target.write('ADtransformed.csv')
# Out:
# {'path': 'ADtransformed.csv'}

# %% [markdown]
# Now you can view your saved data file! Let's also create & save a new resource descriptor for our new data file.

# %%
new_resource=Resource(target)

# %%
new_resource.to_yaml("new_resource.yaml")
# Out:
# "name: alzheimersdisease\nprofile: tabular-data-resource\nscheme: ''\nformat: inline\nschema:\n  fields:\n    - type: string\n      name: AuthorOfPaper\n    - name: YearOfPublication\n      type: any\n    - name: CountryOfOrigin\n      type: any\n    - name: StudyDesign\n      type: any\n    - name: PhaseOfPrevention\n      type: any\n    - name: AgeOfParticipants\n      type: any\n    - name: MenopausalStatus\n      type: any\n    - name: TimingOfHRT\n      type: any\n    - name: HRTDefinition\n      type: any\n    - name: RouteOfAdministration\n      type: any\n    - name: NumberOfCases\n      type: any\n    - name: NumberOfPopulation\n      type: any\n    - name: TypeOfEffectEstimate\n      type: any\n    - name: PointEstimate\n      type: any\n    - name: Lower95%CI\n      type: any\n    - name: Upper95%CI\n      type: any\n    - name: LengthOfFollowUp\n      type: number\n"

# %% [markdown]
# OK now that we've cleaned up the data some, let's add some detail to the metadata.

# %%
new_resource.schema.get_field('LengthOfFollowUp')
# more info: https://framework.frictionlessdata.io/docs/guides/describing-data#describing-a-schema
# Out:
# {'name': 'LengthOfFollowUp', 'type': 'number'}

# %%
new_resource.schema.get_field('LengthOfFollowUp').description = "The unit is Years"

# %%
pprint(new_resource.schema)
# Out:
# {'fields': [{'name': 'AuthorOfPaper', 'type': 'string'},
#             {'name': 'YearOfPublication', 'type': 'any'},
#             {'name': 'CountryOfOrigin', 'type': 'any'},
#             {'name': 'StudyDesign', 'type': 'any'},
#             {'name': 'PhaseOfPrevention', 'type': 'any'},
#             {'name': 'AgeOfParticipants', 'type': 'any'},
#             {'name': 'MenopausalStatus', 'type': 'any'},
#             {'name': 'TimingOfHRT', 'type': 'any'},
#             {'name': 'HRTDefinition', 'type': 'any'},
#             {'name': 'RouteOfAdministration', 'type': 'any'},
#             {'name': 'NumberOfCases', 'type': 'any'},
#             {'name': 'NumberOfPopulation', 'type': 'any'},
#             {'name': 'TypeOfEffectEstimate', 'type': 'any'},
#             {'name': 'PointEstimate', 'type': 'any'},
#             {'name': 'Lower95%CI', 'type': 'any'},
#             {'name': 'Upper95%CI', 'type': 'any'},
#             {'description': 'The unit is Years',
#              'name': 'LengthOfFollowUp',
#              'type': 'number'}]}

# %% [markdown]
# What else do you want to change/update in the metadata or schema? Use the Describe guide to play around with the code. https://framework.frictionlessdata.io/docs/guides/describing-data

# %% [markdown]
# OK Let's Validate the data now!

# %%
from frictionless import validate

# create a report variable to store the validation report 
report = validate(new_resource)
# https://framework.frictionlessdata.io/docs/guides/validation-guide

# %%
# take a look at the validation report
pprint(report)
# Out:
# {'errors': [],
#  'stats': {'errors': 9, 'tasks': 1},
#  'tasks': [{'errors': [{'cell': 'NA',
#                         'cells': ['Brenner',
#                                   '1994',
#                                   'USA',
#                                   'Case-control',
#                                   'Primary',
#                                   '78',
#                                   'NG',
#                                   'Ever',
#                                   'Estrogen',
#                                   'Any',
#                                   '107',
#                                   '120',
#                                   'OR',
#                                   '1.1',
#                                   '0.6',
#                                   '1.8',
#                                   'NA'],
#                         'code': 'type-error',
#                         'description': 'The value does not match the schema '
#                                        'type and format for this field.',
#                         'fieldName': 'LengthOfFollowUp',
#                         'fieldNumber': 17,
#                         'fieldPosition': 17,
#                         'message': 'Type error in the cell "NA" in row "2" and '
#                                    'field "LengthOfFollowUp" at position "17": '
#                                    'type is "number/default"',
#                         'name': 'Type Error',
#                         'note': 'type is "number/default"',
#                         'rowNumber': 1,
#                         'rowPosition': 2,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': 'NA',
#                         'cells': ['Graves',
#                                   '1990',
#                                   'USA',
#                                   'Case-control',
#                                   'Primary',
#                                   '65',
#                                   'NG',
#                                   'Ever',
#                                   'Estrogen',
#                                   'Any',
#                                   '60',
#                                   '60',
#                                   'OR',
#                                   '1.15',
#                                   '0.50',
#                                   '2.64',
#                                   'NA'],
#                         'code': 'type-error',
#                         'description': 'The value does not match the schema '
#                                        'type and format for this field.',
#                         'fieldName': 'LengthOfFollowUp',
#                         'fieldNumber': 17,
#                         'fieldPosition': 17,
#                         'message': 'Type error in the cell "NA" in row "3" and '
#                                    'field "LengthOfFollowUp" at position "17": '
#                                    'type is "number/default"',
#                         'name': 'Type Error',
#                         'note': 'type is "number/default"',
#                         'rowNumber': 2,
#                         'rowPosition': 3,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': 'NA',
#                         'cells': ['Lerner',
#                                   '1997',
#                                   'USA',
#                                   'Case-control',
#                                   'Primary',
#                                   '> 70',
#                                   'NG',
#                                   'Ever',
#                                   'Estrogen',
#                                   'Any',
#                                   '88',
#                                   '176',
#                                   'OR',
#                                   '0.91',
#                                   '0.28',
#                                   '1.54',
#                                   'NA'],
#                         'code': 'type-error',
#                         'description': 'The value does not match the schema '
#                                        'type and format for this field.',
#                         'fieldName': 'LengthOfFollowUp',
#                         'fieldNumber': 17,
#                         'fieldPosition': 17,
#                         'message': 'Type error in the cell "NA" in row "5" and '
#                                    'field "LengthOfFollowUp" at position "17": '
#                                    'type is "number/default"',
#                         'name': 'Type Error',
#                         'note': 'type is "number/default"',
#                         'rowNumber': 4,
#                         'rowPosition': 5,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': 'NA',
#                         'cells': ['Roberts',
#                                   '2006',
#                                   'USA',
#                                   'Case-control',
#                                   'Primary',
#                                   '84',
#                                   'Postmenopausal',
#                                   'Ever',
#                                   'Estrogen',
#                                   'Oral/parenteral',
#                                   '241',
#                                   '241',
#                                   'OR',
#                                   '1.10',
#                                   '0.63',
#                                   '1.93',
#                                   'NA'],
#                         'code': 'type-error',
#                         'description': 'The value does not match the schema '
#                                        'type and format for this field.',
#                         'fieldName': 'LengthOfFollowUp',
#                         'fieldNumber': 17,
#                         'fieldPosition': 17,
#                         'message': 'Type error in the cell "NA" in row "8" and '
#                                    'field "LengthOfFollowUp" at position "17": '
#                                    'type is "number/default"',
#                         'name': 'Type Error',
#                         'note': 'type is "number/default"',
#                         'rowNumber': 7,
#                         'rowPosition': 8,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': '1â€“5',
#                         'cells': ['Tang',
#                                   '1996',
#                                   'USA',
#                                   'Cohort',
#                                   'Primary',
#                                   '74',
#                                   'Postmenopausal',
#                                   'Ever',
#                                   'Estrogen',
#                                   'Oral',
#                                   '167',
#                                   '1124',
#                                   'HR',
#                                   '0.50',
#                                   '0.25',
#                                   '0.90',
#                                   '1â€“5'],
#                         'code': 'type-error',
#                         'description': 'The value does not match the schema '
#                                        'type and format for this field.',
#                         'fieldName': 'LengthOfFollowUp',
#                         'fieldNumber': 17,
#                         'fieldPosition': 17,
#                         'message': 'Type error in the cell "1â€“5" in row "13" '
#                                    'and field "LengthOfFollowUp" at position '
#                                    '"17": type is "number/default"',
#                         'name': 'Type Error',
#                         'note': 'type is "number/default"',
#                         'rowNumber': 12,
#                         'rowPosition': 13,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': 'NA',
#                         'cells': ['Waring',
#                                   '1999',
#                                   'USA',
#                                   'Case-control',
#                                   'Primary',
#                                   '82',
#                                   'Postmenopausal',
#                                   'Ever',
#                                   'Estrogen',
#                                   'Any',
#                                   '222',
#                                   '222',
#                                   'OR',
#                                   '0.48',
#                                   '0.22',
#                                   '1.01',
#                                   'NA'],
#                         'code': 'type-error',
#                         'description': 'The value does not match the schema '
#                                        'type and format for this field.',
#                         'fieldName': 'LengthOfFollowUp',
#                         'fieldNumber': 17,
#                         'fieldPosition': 17,
#                         'message': 'Type error in the cell "NA" in row "14" '
#                                    'and field "LengthOfFollowUp" at position '
#                                    '"17": type is "number/default"',
#                         'name': 'Type Error',
#                         'note': 'type is "number/default"',
#                         'rowNumber': 13,
#                         'rowPosition': 14,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': 'NA',
#                         'cells': ['Brenner',
#                                   '1994',
#                                   'USA',
#                                   'Case-control',
#                                   'Primary',
#                                   '78',
#                                   'NG',
#                                   'Past',
#                                   'Estrogen',
#                                   'Any',
#                                   '107',
#                                   '120',
#                                   'OR',
#                                   '1.7',
#                                   '0.9',
#                                   '3.2',
#                                   'NA'],
#                         'code': 'type-error',
#                         'description': 'The value does not match the schema '
#                                        'type and format for this field.',
#                         'fieldName': 'LengthOfFollowUp',
#                         'fieldNumber': 17,
#                         'fieldPosition': 17,
#                         'message': 'Type error in the cell "NA" in row "16" '
#                                    'and field "LengthOfFollowUp" at position '
#                                    '"17": type is "number/default"',
#                         'name': 'Type Error',
#                         'note': 'type is "number/default"',
#                         'rowNumber': 15,
#                         'rowPosition': 16,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': 'NA',
#                         'cells': ['Brenner',
#                                   '1994',
#                                   'USA',
#                                   'Case-control',
#                                   'Primary',
#                                   '78',
#                                   'NG',
#                                   'Current',
#                                   'Estrogen',
#                                   'Any',
#                                   '107',
#                                   '120',
#                                   'OR',
#                                   '0.6',
#                                   '0.3',
#                                   '1.2',
#                                   'NA'],
#                         'code': 'type-error',
#                         'description': 'The value does not match the schema '
#                                        'type and format for this field.',
#                         'fieldName': 'LengthOfFollowUp',
#                         'fieldNumber': 17,
#                         'fieldPosition': 17,
#                         'message': 'Type error in the cell "NA" in row "19" '
#                                    'and field "LengthOfFollowUp" at position '
#                                    '"17": type is "number/default"',
#                         'name': 'Type Error',
#                         'note': 'type is "number/default"',
#                         'rowNumber': 18,
#                         'rowPosition': 19,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cells': ['',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   ''],
#                         'code': 'blank-row',
#                         'description': 'This row is empty. A row should '
#                                        'contain at least one value.',
#                         'message': 'Row at position "27" is completely blank',
#                         'name': 'Blank Row',
#                         'note': '',
#                         'rowNumber': 26,
#                         'rowPosition': 27,
#                         'tags': ['#table', '#row']}],
#             'partial': False,
#             'resource': {'data': <frictionless.transform.resource.DataWithErrorHandling object at 0x11d752cd0>,
#                          'format': 'inline',
#                          'hashing': 'md5',
#                          'name': 'alzheimersdisease',
#                          'profile': 'tabular-data-resource',
#                          'schema': {'fields': [{'name': 'AuthorOfPaper',
#                                                 'type': 'string'},
#                                                {'name': 'YearOfPublication',
#                                                 'type': 'any'},
#                                                {'name': 'CountryOfOrigin',
#                                                 'type': 'any'},
#                                                {'name': 'StudyDesign',
#                                                 'type': 'any'},
#                                                {'name': 'PhaseOfPrevention',
#                                                 'type': 'any'},
#                                                {'name': 'AgeOfParticipants',
#                                                 'type': 'any'},
#                                                {'name': 'MenopausalStatus',
#                                                 'type': 'any'},
#                                                {'name': 'TimingOfHRT',
#                                                 'type': 'any'},
#                                                {'name': 'HRTDefinition',
#                                                 'type': 'any'},
#                                                {'name': 'RouteOfAdministration',
#                                                 'type': 'any'},
#                                                {'name': 'NumberOfCases',
#                                                 'type': 'any'},
#                                                {'name': 'NumberOfPopulation',
#                                                 'type': 'any'},
#                                                {'name': 'TypeOfEffectEstimate',
#                                                 'type': 'any'},
#                                                {'name': 'PointEstimate',
#                                                 'type': 'any'},
#                                                {'name': 'Lower95%CI',
#                                                 'type': 'any'},
#                                                {'name': 'Upper95%CI',
#                                                 'type': 'any'},
#                                                {'description': 'The unit is '
#                                                                'Years',
#                                                 'name': 'LengthOfFollowUp',
#                                                 'type': 'number'}]},
#                          'scheme': '',
#                          'stats': {'bytes': 0,
#                                    'fields': 17,
#                                    'hash': '',
#                                    'rows': 29}},
#             'scope': ['hash-count-error',
#                       'byte-count-error',
#                       'field-count-error',
#                       'row-count-error',
#                       'blank-header',
#                       'extra-label',
#                       'missing-label',
#                       'blank-label',
#                       'duplicate-label',
#                       'incorrect-label',
#                       'blank-row',
#                       'primary-key-error',
#                       'foreign-key-error',
#                       'extra-cell',
#                       'missing-cell',
#                       'type-error',
#                       'constraint-error',
#                       'unique-error'],
#             'stats': {'errors': 9},
#             'time': 0.075,
#             'valid': False}],
#  'time': 0.075,
#  'valid': False,
#  'version': '4.28.1'}

# %% [markdown]
# What errors are you finding?

# %% [markdown]
# ...did you look?

# %% [markdown]
# It looks like we are getting errors in 'LengthOfFollowUp'. Let's manipulate the Report to make it easier to read.

# %%
# https://framework.frictionlessdata.io/docs/guides/validation-guide#validation-report
pprint(report.flatten(["rowPosition", "fieldPosition", "code", "message"]))
# Out:
# [[2,
#   17,
#   'type-error',
#   'Type error in the cell "NA" in row "2" and field "LengthOfFollowUp" at '
#   'position "17": type is "number/default"'],
#  [3,
#   17,
#   'type-error',
#   'Type error in the cell "NA" in row "3" and field "LengthOfFollowUp" at '
#   'position "17": type is "number/default"'],
#  [5,
#   17,
#   'type-error',
#   'Type error in the cell "NA" in row "5" and field "LengthOfFollowUp" at '
#   'position "17": type is "number/default"'],
#  [8,
#   17,
#   'type-error',
#   'Type error in the cell "NA" in row "8" and field "LengthOfFollowUp" at '
#   'position "17": type is "number/default"'],
#  [13,
#   17,
#   'type-error',
#   'Type error in the cell "1â€“5" in row "13" and field "LengthOfFollowUp" at '
#   'position "17": type is "number/default"'],
#  [14,
#   17,
#   'type-error',
#   'Type error in the cell "NA" in row "14" and field "LengthOfFollowUp" at '
#   'position "17": type is "number/default"'],
#  [16,
#   17,
#   'type-error',
#   'Type error in the cell "NA" in row "16" and field "LengthOfFollowUp" at '
#   'position "17": type is "number/default"'],
#  [19,
#   17,
#   'type-error',
#   'Type error in the cell "NA" in row "19" and field "LengthOfFollowUp" at '
#   'position "17": type is "number/default"'],
#  [27, None, 'blank-row', 'Row at position "27" is completely blank']]

# %% [markdown]
# Now we can more easily see that these errors are all type errors, and we can see which row they are occuring in.
#
# Why are we getting "NA" as an error? "NA" is being read-in as a string, but it should be recognized as a missing value. We can fix that!

# %%
new_resource.schema.missing_values = ["NA"]

# %%
# let's check to see if it is valid now!
report2 = validate(new_resource)
pprint(report2)
# Out:
# {'errors': [],
#  'stats': {'errors': 5, 'tasks': 1},
#  'tasks': [{'errors': [{'cell': '1â€“5',
#                         'cells': ['Tang',
#                                   '1996',
#                                   'USA',
#                                   'Cohort',
#                                   'Primary',
#                                   '74',
#                                   'Postmenopausal',
#                                   'Ever',
#                                   'Estrogen',
#                                   'Oral',
#                                   '167',
#                                   '1124',
#                                   'HR',
#                                   '0.50',
#                                   '0.25',
#                                   '0.90',
#                                   '1â€“5'],
#                         'code': 'type-error',
#                         'description': 'The value does not match the schema '
#                                        'type and format for this field.',
#                         'fieldName': 'LengthOfFollowUp',
#                         'fieldNumber': 17,
#                         'fieldPosition': 17,
#                         'message': 'Type error in the cell "1â€“5" in row "13" '
#                                    'and field "LengthOfFollowUp" at position '
#                                    '"17": type is "number/default"',
#                         'name': 'Type Error',
#                         'note': 'type is "number/default"',
#                         'rowNumber': 12,
#                         'rowPosition': 13,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': '',
#                         'cells': ['',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   ''],
#                         'code': 'type-error',
#                         'description': 'The value does not match the schema '
#                                        'type and format for this field.',
#                         'fieldName': 'LengthOfFollowUp',
#                         'fieldNumber': 17,
#                         'fieldPosition': 17,
#                         'message': 'Type error in the cell "" in row "27" and '
#                                    'field "LengthOfFollowUp" at position "17": '
#                                    'type is "number/default"',
#                         'name': 'Type Error',
#                         'note': 'type is "number/default"',
#                         'rowNumber': 26,
#                         'rowPosition': 27,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': '',
#                         'cells': ['COMMENTS',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   ''],
#                         'code': 'type-error',
#                         'description': 'The value does not match the schema '
#                                        'type and format for this field.',
#                         'fieldName': 'LengthOfFollowUp',
#                         'fieldNumber': 17,
#                         'fieldPosition': 17,
#                         'message': 'Type error in the cell "" in row "28" and '
#                                    'field "LengthOfFollowUp" at position "17": '
#                                    'type is "number/default"',
#                         'name': 'Type Error',
#                         'note': 'type is "number/default"',
#                         'rowNumber': 27,
#                         'rowPosition': 28,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': '',
#                         'cells': ['1. Study-specific risk estimates with the '
#                                   'maximum number of adjusted confounding '
#                                   'variables were analyzed where available.',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   ''],
#                         'code': 'type-error',
#                         'description': 'The value does not match the schema '
#                                        'type and format for this field.',
#                         'fieldName': 'LengthOfFollowUp',
#                         'fieldNumber': 17,
#                         'fieldPosition': 17,
#                         'message': 'Type error in the cell "" in row "29" and '
#                                    'field "LengthOfFollowUp" at position "17": '
#                                    'type is "number/default"',
#                         'name': 'Type Error',
#                         'note': 'type is "number/default"',
#                         'rowNumber': 28,
#                         'rowPosition': 29,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': '',
#                         'cells': ["2. If studies did not distinguish 'current "
#                                   "use of HRT' from 'past use of HRT', they "
#                                   "were categorized under 'ever use of HRT'.",
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   ''],
#                         'code': 'type-error',
#                         'description': 'The value does not match the schema '
#                                        'type and format for this field.',
#                         'fieldName': 'LengthOfFollowUp',
#                         'fieldNumber': 17,
#                         'fieldPosition': 17,
#                         'message': 'Type error in the cell "" in row "30" and '
#                                    'field "LengthOfFollowUp" at position "17": '
#                                    'type is "number/default"',
#                         'name': 'Type Error',
#                         'note': 'type is "number/default"',
#                         'rowNumber': 29,
#                         'rowPosition': 30,
#                         'tags': ['#table', '#row', '#cell']}],
#             'partial': False,
#             'resource': {'data': <frictionless.transform.resource.DataWithErrorHandling object at 0x11d752cd0>,
#                          'format': 'inline',
#                          'hashing': 'md5',
#                          'name': 'alzheimersdisease',
#                          'profile': 'tabular-data-resource',
#                          'schema': {'fields': [{'name': 'AuthorOfPaper',
#                                                 'type': 'string'},
#                                                {'name': 'YearOfPublication',
#                                                 'type': 'any'},
#                                                {'name': 'CountryOfOrigin',
#                                                 'type': 'any'},
#                                                {'name': 'StudyDesign',
#                                                 'type': 'any'},
#                                                {'name': 'PhaseOfPrevention',
#                                                 'type': 'any'},
#                                                {'name': 'AgeOfParticipants',
#                                                 'type': 'any'},
#                                                {'name': 'MenopausalStatus',
#                                                 'type': 'any'},
#                                                {'name': 'TimingOfHRT',
#                                                 'type': 'any'},
#                                                {'name': 'HRTDefinition',
#                                                 'type': 'any'},
#                                                {'name': 'RouteOfAdministration',
#                                                 'type': 'any'},
#                                                {'name': 'NumberOfCases',
#                                                 'type': 'any'},
#                                                {'name': 'NumberOfPopulation',
#                                                 'type': 'any'},
#                                                {'name': 'TypeOfEffectEstimate',
#                                                 'type': 'any'},
#                                                {'name': 'PointEstimate',
#                                                 'type': 'any'},
#                                                {'name': 'Lower95%CI',
#                                                 'type': 'any'},
#                                                {'name': 'Upper95%CI',
#                                                 'type': 'any'},
#                                                {'description': 'The unit is '
#                                                                'Years',
#                                                 'name': 'LengthOfFollowUp',
#                                                 'type': 'number'}],
#                                     'missingValues': ['NA']},
#                          'scheme': '',
#                          'stats': {'bytes': 0,
#                                    'fields': 17,
#                                    'hash': '',
#                                    'rows': 29}},
#             'scope': ['hash-count-error',
#                       'byte-count-error',
#                       'field-count-error',
#                       'row-count-error',
#                       'blank-header',
#                       'extra-label',
#                       'missing-label',
#                       'blank-label',
#                       'duplicate-label',
#                       'incorrect-label',
#                       'blank-row',
#                       'primary-key-error',
#                       'foreign-key-error',
#                       'extra-cell',
#                       'missing-cell',
#                       'type-error',
#                       'constraint-error',
#                       'unique-error'],
#             'stats': {'errors': 5},
#             'time': 0.075,
#             'valid': False}],
#  'time': 0.075,
#  'valid': False,
#  'version': '4.28.1'}

# %% [markdown]
# Nice! Those type errors are all gone now! (Note: you might see other errors though...this is from the last 2 rows in the dataset that are not really data. Take a look at them...)

# %% [markdown]
# Now we can add in some data constraints for fun. We can create data constraints that limit the content of the data. https://specs.frictionlessdata.io/table-schema/#constraints
#
# We'll start by adding a constraint to the PointEstimate column. Let's say that all the values need to be less than one, so we'll add in a maximum of 1.

# %%
constrained_resource = describe('ADtransformed.csv')
#note that if your data types are "any" you will need to update them.
constrained_resource.schema.get_field('PointEstimate').type = "number"
constrained_resource.schema.get_field('PointEstimate').constraints["maximum"] = 1
# this means that only values of "M" are acceptable for the "sex" column

# %%
# save this descriptor
constrained_resource.to_yaml("constrained_resourceAD.yaml")
# Out:
# 'path: ADtransformed.csv\nname: adtransformed\nprofile: tabular-data-resource\nscheme: file\nformat: csv\nhashing: md5\nencoding: utf-8\ndialect:\n  quoteChar: \'"\'\nschema:\n  fields:\n    - type: string\n      name: AuthorOfPaper\n    - name: YearOfPublication\n      type: any\n    - name: CountryOfOrigin\n      type: any\n    - name: StudyDesign\n      type: any\n    - name: PhaseOfPrevention\n      type: any\n    - name: AgeOfParticipants\n      type: any\n    - name: MenopausalStatus\n      type: any\n    - name: TimingOfHRT\n      type: any\n    - name: HRTDefinition\n      type: any\n    - name: RouteOfAdministration\n      type: any\n    - name: NumberOfCases\n      type: any\n    - name: NumberOfPopulation\n      type: any\n    - name: TypeOfEffectEstimate\n      type: any\n    - name: PointEstimate\n      type: number\n      constraints:\n        maximum: 1\n    - name: Lower95%CI\n      type: any\n    - name: Upper95%CI\n      type: any\n    - name: LengthOfFollowUp\n      type: any\n'

# %%
# create a new validation report
report3 = validate(constrained_resource)
pprint(report3)
# Out:
# {'errors': [],
#  'stats': {'errors': 13, 'tasks': 1},
#  'tasks': [{'errors': [{'cell': '1.1',
#                         'cells': ['Brenner',
#                                   '1994',
#                                   'USA',
#                                   'Case-control',
#                                   'Primary',
#                                   '78',
#                                   'NG',
#                                   'Ever',
#                                   'Estrogen',
#                                   'Any',
#                                   '107',
#                                   '120',
#                                   'OR',
#                                   '1.1',
#                                   '0.6',
#                                   '1.8',
#                                   ''],
#                         'code': 'constraint-error',
#                         'description': 'A field value does not conform to a '
#                                        'constraint.',
#                         'fieldName': 'PointEstimate',
#                         'fieldNumber': 14,
#                         'fieldPosition': 14,
#                         'message': 'The cell "1.1" in row at position "2" and '
#                                    'field "PointEstimate" at position "14" '
#                                    'does not conform to a constraint: '
#                                    'constraint "maximum" is "1"',
#                         'name': 'Constraint Error',
#                         'note': 'constraint "maximum" is "1"',
#                         'rowNumber': 1,
#                         'rowPosition': 2,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': '1.15',
#                         'cells': ['Graves',
#                                   '1990',
#                                   'USA',
#                                   'Case-control',
#                                   'Primary',
#                                   '65',
#                                   'NG',
#                                   'Ever',
#                                   'Estrogen',
#                                   'Any',
#                                   '60',
#                                   '60',
#                                   'OR',
#                                   '1.15',
#                                   '0.50',
#                                   '2.64',
#                                   ''],
#                         'code': 'constraint-error',
#                         'description': 'A field value does not conform to a '
#                                        'constraint.',
#                         'fieldName': 'PointEstimate',
#                         'fieldNumber': 14,
#                         'fieldPosition': 14,
#                         'message': 'The cell "1.15" in row at position "3" and '
#                                    'field "PointEstimate" at position "14" '
#                                    'does not conform to a constraint: '
#                                    'constraint "maximum" is "1"',
#                         'name': 'Constraint Error',
#                         'note': 'constraint "maximum" is "1"',
#                         'rowNumber': 2,
#                         'rowPosition': 3,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': '1.37',
#                         'cells': ['Lindsay',
#                                   '2002',
#                                   'Canada',
#                                   'Cohort',
#                                   'Primary',
#                                   '73',
#                                   'NG',
#                                   'Ever',
#                                   'Estrogen',
#                                   'Any',
#                                   '110',
#                                   '2079',
#                                   'OR',
#                                   '1.37',
#                                   '0.48',
#                                   '3.95',
#                                   '5'],
#                         'code': 'constraint-error',
#                         'description': 'A field value does not conform to a '
#                                        'constraint.',
#                         'fieldName': 'PointEstimate',
#                         'fieldNumber': 14,
#                         'fieldPosition': 14,
#                         'message': 'The cell "1.37" in row at position "6" and '
#                                    'field "PointEstimate" at position "14" '
#                                    'does not conform to a constraint: '
#                                    'constraint "maximum" is "1"',
#                         'name': 'Constraint Error',
#                         'note': 'constraint "maximum" is "1"',
#                         'rowNumber': 5,
#                         'rowPosition': 6,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': '1.10',
#                         'cells': ['Roberts',
#                                   '2006',
#                                   'USA',
#                                   'Case-control',
#                                   'Primary',
#                                   '84',
#                                   'Postmenopausal',
#                                   'Ever',
#                                   'Estrogen',
#                                   'Oral/parenteral',
#                                   '241',
#                                   '241',
#                                   'OR',
#                                   '1.10',
#                                   '0.63',
#                                   '1.93',
#                                   ''],
#                         'code': 'constraint-error',
#                         'description': 'A field value does not conform to a '
#                                        'constraint.',
#                         'fieldName': 'PointEstimate',
#                         'fieldNumber': 14,
#                         'fieldPosition': 14,
#                         'message': 'The cell "1.10" in row at position "8" and '
#                                    'field "PointEstimate" at position "14" '
#                                    'does not conform to a constraint: '
#                                    'constraint "maximum" is "1"',
#                         'name': 'Constraint Error',
#                         'note': 'constraint "maximum" is "1"',
#                         'rowNumber': 7,
#                         'rowPosition': 8,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': '1.19',
#                         'cells': ['Seshadri',
#                                   '2001',
#                                   'UK',
#                                   'Nested case-control',
#                                   'Primary',
#                                   '66',
#                                   'Postmenopausal',
#                                   'Ever',
#                                   'Any',
#                                   'Oral/transdermal',
#                                   '62',
#                                   '221',
#                                   'OR',
#                                   '1.19',
#                                   '0.62',
#                                   '2.27',
#                                   '5.3'],
#                         'code': 'constraint-error',
#                         'description': 'A field value does not conform to a '
#                                        'constraint.',
#                         'fieldName': 'PointEstimate',
#                         'fieldNumber': 14,
#                         'fieldPosition': 14,
#                         'message': 'The cell "1.19" in row at position "9" and '
#                                    'field "PointEstimate" at position "14" '
#                                    'does not conform to a constraint: '
#                                    'constraint "maximum" is "1"',
#                         'name': 'Constraint Error',
#                         'note': 'constraint "maximum" is "1"',
#                         'rowNumber': 8,
#                         'rowPosition': 9,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': '1.7',
#                         'cells': ['Brenner',
#                                   '1994',
#                                   'USA',
#                                   'Case-control',
#                                   'Primary',
#                                   '78',
#                                   'NG',
#                                   'Past',
#                                   'Estrogen',
#                                   'Any',
#                                   '107',
#                                   '120',
#                                   'OR',
#                                   '1.7',
#                                   '0.9',
#                                   '3.2',
#                                   ''],
#                         'code': 'constraint-error',
#                         'description': 'A field value does not conform to a '
#                                        'constraint.',
#                         'fieldName': 'PointEstimate',
#                         'fieldNumber': 14,
#                         'fieldPosition': 14,
#                         'message': 'The cell "1.7" in row at position "16" and '
#                                    'field "PointEstimate" at position "14" '
#                                    'does not conform to a constraint: '
#                                    'constraint "maximum" is "1"',
#                         'name': 'Constraint Error',
#                         'note': 'constraint "maximum" is "1"',
#                         'rowNumber': 15,
#                         'rowPosition': 16,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': '1.22',
#                         'cells': ['Petitti (1)',
#                                   '2008',
#                                   'USA',
#                                   'Cohort',
#                                   'Primary',
#                                   '79',
#                                   'NG',
#                                   'Current',
#                                   'Estrogen',
#                                   'Oral',
#                                   '191',
#                                   '2906',
#                                   'HR',
#                                   '1.22',
#                                   '0.89',
#                                   '1.68',
#                                   '4'],
#                         'code': 'constraint-error',
#                         'description': 'A field value does not conform to a '
#                                        'constraint.',
#                         'fieldName': 'PointEstimate',
#                         'fieldNumber': 14,
#                         'fieldPosition': 14,
#                         'message': 'The cell "1.22" in row at position "20" '
#                                    'and field "PointEstimate" at position "14" '
#                                    'does not conform to a constraint: '
#                                    'constraint "maximum" is "1"',
#                         'name': 'Constraint Error',
#                         'note': 'constraint "maximum" is "1"',
#                         'rowNumber': 19,
#                         'rowPosition': 20,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': '1.41',
#                         'cells': ['Petitti (2)',
#                                   '2008',
#                                   'USA',
#                                   'Cohort',
#                                   'Primary',
#                                   '79',
#                                   'NG',
#                                   'Current',
#                                   'Combined',
#                                   'Oral',
#                                   '191',
#                                   '2906',
#                                   'HR',
#                                   '1.41',
#                                   '0.94',
#                                   '2.12',
#                                   '4'],
#                         'code': 'constraint-error',
#                         'description': 'A field value does not conform to a '
#                                        'constraint.',
#                         'fieldName': 'PointEstimate',
#                         'fieldNumber': 14,
#                         'fieldPosition': 14,
#                         'message': 'The cell "1.41" in row at position "21" '
#                                    'and field "PointEstimate" at position "14" '
#                                    'does not conform to a constraint: '
#                                    'constraint "maximum" is "1"',
#                         'name': 'Constraint Error',
#                         'note': 'constraint "maximum" is "1"',
#                         'rowNumber': 20,
#                         'rowPosition': 21,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': '1.36',
#                         'cells': ['Ryan',
#                                   '2009',
#                                   'France',
#                                   'Cohort',
#                                   'Primary',
#                                   '74',
#                                   'Postmenopausal',
#                                   'Current',
#                                   'Any',
#                                   'Any',
#                                   '53',
#                                   '3130',
#                                   'HR',
#                                   '1.36',
#                                   '0.44',
#                                   '4.20',
#                                   '4'],
#                         'code': 'constraint-error',
#                         'description': 'A field value does not conform to a '
#                                        'constraint.',
#                         'fieldName': 'PointEstimate',
#                         'fieldNumber': 14,
#                         'fieldPosition': 14,
#                         'message': 'The cell "1.36" in row at position "22" '
#                                    'and field "PointEstimate" at position "14" '
#                                    'does not conform to a constraint: '
#                                    'constraint "maximum" is "1"',
#                         'name': 'Constraint Error',
#                         'note': 'constraint "maximum" is "1"',
#                         'rowNumber': 21,
#                         'rowPosition': 22,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': '1.18',
#                         'cells': ['Seshadri (overall)',
#                                   '2001',
#                                   'UK',
#                                   'Nested case-control',
#                                   'Primary',
#                                   '66',
#                                   'Postmenopausal',
#                                   'Current',
#                                   'Any',
#                                   'Oral/transdermal',
#                                   '59',
#                                   '221',
#                                   'OR',
#                                   '1.18',
#                                   '0.59',
#                                   '2.37',
#                                   '5.3'],
#                         'code': 'constraint-error',
#                         'description': 'A field value does not conform to a '
#                                        'constraint.',
#                         'fieldName': 'PointEstimate',
#                         'fieldNumber': 14,
#                         'fieldPosition': 14,
#                         'message': 'The cell "1.18" in row at position "23" '
#                                    'and field "PointEstimate" at position "14" '
#                                    'does not conform to a constraint: '
#                                    'constraint "maximum" is "1"',
#                         'name': 'Constraint Error',
#                         'note': 'constraint "maximum" is "1"',
#                         'rowNumber': 22,
#                         'rowPosition': 23,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': '1.45',
#                         'cells': ['Seshadri (2)',
#                                   '2001',
#                                   'UK',
#                                   'Nested case-control',
#                                   'Primary',
#                                   '66',
#                                   'Postmenopausal',
#                                   'Current',
#                                   'Combined',
#                                   'Oral',
#                                   '59',
#                                   '221',
#                                   'OR',
#                                   '1.45',
#                                   '0.60',
#                                   '3.49',
#                                   '5.3'],
#                         'code': 'constraint-error',
#                         'description': 'A field value does not conform to a '
#                                        'constraint.',
#                         'fieldName': 'PointEstimate',
#                         'fieldNumber': 14,
#                         'fieldPosition': 14,
#                         'message': 'The cell "1.45" in row at position "25" '
#                                    'and field "PointEstimate" at position "14" '
#                                    'does not conform to a constraint: '
#                                    'constraint "maximum" is "1"',
#                         'name': 'Constraint Error',
#                         'note': 'constraint "maximum" is "1"',
#                         'rowNumber': 24,
#                         'rowPosition': 25,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cell': '1.08',
#                         'cells': ['Zandi',
#                                   '2002',
#                                   'USA',
#                                   'Cohort',
#                                   'Primary',
#                                   '75',
#                                   'NG',
#                                   'Current',
#                                   'Any',
#                                   'Any',
#                                   '84',
#                                   '1866',
#                                   'HR',
#                                   '1.08',
#                                   '0.59',
#                                   '1.91',
#                                   '3'],
#                         'code': 'constraint-error',
#                         'description': 'A field value does not conform to a '
#                                        'constraint.',
#                         'fieldName': 'PointEstimate',
#                         'fieldNumber': 14,
#                         'fieldPosition': 14,
#                         'message': 'The cell "1.08" in row at position "26" '
#                                    'and field "PointEstimate" at position "14" '
#                                    'does not conform to a constraint: '
#                                    'constraint "maximum" is "1"',
#                         'name': 'Constraint Error',
#                         'note': 'constraint "maximum" is "1"',
#                         'rowNumber': 25,
#                         'rowPosition': 26,
#                         'tags': ['#table', '#row', '#cell']},
#                        {'cells': ['',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   '',
#                                   ''],
#                         'code': 'blank-row',
#                         'description': 'This row is empty. A row should '
#                                        'contain at least one value.',
#                         'message': 'Row at position "27" is completely blank',
#                         'name': 'Blank Row',
#                         'note': '',
#                         'rowNumber': 26,
#                         'rowPosition': 27,
#                         'tags': ['#table', '#row']}],
#             'partial': False,
#             'resource': {'dialect': {'quoteChar': '"'},
#                          'encoding': 'utf-8',
#                          'format': 'csv',
#                          'hashing': 'md5',
#                          'name': 'adtransformed',
#                          'path': 'ADtransformed.csv',
#                          'profile': 'tabular-data-resource',
#                          'schema': {'fields': [{'name': 'AuthorOfPaper',
#                                                 'type': 'string'},
#                                                {'name': 'YearOfPublication',
#                                                 'type': 'any'},
#                                                {'name': 'CountryOfOrigin',
#                                                 'type': 'any'},
#                                                {'name': 'StudyDesign',
#                                                 'type': 'any'},
#                                                {'name': 'PhaseOfPrevention',
#                                                 'type': 'any'},
#                                                {'name': 'AgeOfParticipants',
#                                                 'type': 'any'},
#                                                {'name': 'MenopausalStatus',
#                                                 'type': 'any'},
#                                                {'name': 'TimingOfHRT',
#                                                 'type': 'any'},
#                                                {'name': 'HRTDefinition',
#                                                 'type': 'any'},
#                                                {'name': 'RouteOfAdministration',
#                                                 'type': 'any'},
#                                                {'name': 'NumberOfCases',
#                                                 'type': 'any'},
#                                                {'name': 'NumberOfPopulation',
#                                                 'type': 'any'},
#                                                {'name': 'TypeOfEffectEstimate',
#                                                 'type': 'any'},
#                                                {'constraints': {'maximum': 1},
#                                                 'name': 'PointEstimate',
#                                                 'type': 'number'},
#                                                {'name': 'Lower95%CI',
#                                                 'type': 'any'},
#                                                {'name': 'Upper95%CI',
#                                                 'type': 'any'},
#                                                {'name': 'LengthOfFollowUp',
#                                                 'type': 'any'}]},
#                          'scheme': 'file',
#                          'stats': {'bytes': 3033,
#                                    'fields': 17,
#                                    'hash': '750f69c83bd43528af04da8fcfdcaae9',
#                                    'rows': 29}},
#             'scope': ['hash-count-error',
#                       'byte-count-error',
#                       'field-count-error',
#                       'row-count-error',
#                       'blank-header',
#                       'extra-label',
#                       'missing-label',
#                       'blank-label',
#                       'duplicate-label',
#                       'incorrect-label',
#                       'blank-row',
#                       'primary-key-error',
#                       'foreign-key-error',
#                       'extra-cell',
#                       'missing-cell',
#                       'type-error',
#                       'constraint-error',
#                       'unique-error'],
#             'stats': {'errors': 13},
#             'time': 0.078,
#             'valid': False}],
#  'time': 0.078,
#  'valid': False,
#  'version': '4.28.1'}

# %% [markdown]
# You can see that the there are now errors for the values that are over 1! What other constraints can you add?

# %% [markdown]
# Let's end by Packaging the data.

# %%
from frictionless import Package
package = Package(resources=Resource(path='ADtransformed.csv'), descriptor='constrained_resourceAD.yaml') 
# this package contains the data file + the descriptor file.

# %%
# let's look at the package
pprint(package)
# Out:
# {'dialect': {'quoteChar': '"'},
#  'encoding': 'utf-8',
#  'format': 'csv',
#  'hashing': 'md5',
#  'name': 'adtransformed',
#  'path': 'ADtransformed.csv',
#  'profile': 'tabular-data-resource',
#  'resources': {'path': 'ADtransformed.csv'},
#  'schema': {'fields': [{'name': 'AuthorOfPaper', 'type': 'string'},
#                        {'name': 'YearOfPublication', 'type': 'any'},
#                        {'name': 'CountryOfOrigin', 'type': 'any'},
#                        {'name': 'StudyDesign', 'type': 'any'},
#                        {'name': 'PhaseOfPrevention', 'type': 'any'},
#                        {'name': 'AgeOfParticipants', 'type': 'any'},
#                        {'name': 'MenopausalStatus', 'type': 'any'},
#                        {'name': 'TimingOfHRT', 'type': 'any'},
#                        {'name': 'HRTDefinition', 'type': 'any'},
#                        {'name': 'RouteOfAdministration', 'type': 'any'},
#                        {'name': 'NumberOfCases', 'type': 'any'},
#                        {'name': 'NumberOfPopulation', 'type': 'any'},
#                        {'name': 'TypeOfEffectEstimate', 'type': 'any'},
#                        {'constraints': {'maximum': 1},
#                         'name': 'PointEstimate',
#                         'type': 'number'},
#                        {'name': 'Lower95%CI', 'type': 'any'},
#                        {'name': 'Upper95%CI', 'type': 'any'},
#                        {'name': 'LengthOfFollowUp', 'type': 'any'}]},
#  'scheme': 'file'}

# %%
# save the package
package.to_yaml('package.yaml')
# package.to_json('package.json') will save as JSON instead
# Out:
# 'resources:\n  path: ADtransformed.csv\npath: ADtransformed.csv\nname: adtransformed\nprofile: tabular-data-resource\nscheme: file\nformat: csv\nhashing: md5\nencoding: utf-8\ndialect:\n  quoteChar: \'"\'\nschema:\n  fields:\n    - type: string\n      name: AuthorOfPaper\n    - name: YearOfPublication\n      type: any\n    - name: CountryOfOrigin\n      type: any\n    - name: StudyDesign\n      type: any\n    - name: PhaseOfPrevention\n      type: any\n    - name: AgeOfParticipants\n      type: any\n    - name: MenopausalStatus\n      type: any\n    - name: TimingOfHRT\n      type: any\n    - name: HRTDefinition\n      type: any\n    - name: RouteOfAdministration\n      type: any\n    - name: NumberOfCases\n      type: any\n    - name: NumberOfPopulation\n      type: any\n    - name: TypeOfEffectEstimate\n      type: any\n    - name: PointEstimate\n      type: number\n      constraints:\n        maximum: 1\n    - name: Lower95%CI\n      type: any\n    - name: Upper95%CI\n      type: any\n    - name: LengthOfFollowUp\n      type: any\n'

# %% [markdown]
# And that's it! Now you can publish the package, which contains your data, metadata + schema!
